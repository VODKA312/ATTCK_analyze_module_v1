# %%
import json
import pandas as pd

# 读取JSON文件
with open('../clustering/frequency_id.json', 'r') as json_file:
    data = json.load(json_file)

# 过滤出usage_count大于25的数据
filtered_data = [entry for entry in data if entry['usage_count'] > 25]

# 提取technique_id
technique_ids = [entry['technique_id'] for entry in filtered_data]

print(technique_ids)
# Out:
# [['T1021.001', 'T1018', 'T1047'], ['T1583.001', 'T1140', 'T1189'], ['T1033'], ['T1005', 'T1003.001'], ['T1057'], ['T1016', 'T1078'], ['T1083', 'T1070.004'], ['T1203', 'T1204.001'], ['T1566.002'], ['T1082'], ['T1059.005'], ['T1053.005'], ['T1036.005'], ['T1071.001'], ['T1547.001'], ['T1059.003'], ['T1588.002'], ['T1059.001'], ['T1027'], ['T1105'], ['T1566.001'], ['T1204.002']]

# %%
high_frequency_id = []
for i in technique_ids:
    for j in i:
        high_frequency_id.append(j)

# %%
print(high_frequency_id)
# Out:
# ['T1021.001', 'T1018', 'T1047', 'T1583.001', 'T1140', 'T1189', 'T1033', 'T1005', 'T1003.001', 'T1057', 'T1016', 'T1078', 'T1083', 'T1070.004', 'T1203', 'T1204.001', 'T1566.002', 'T1082', 'T1059.005', 'T1053.005', 'T1036.005', 'T1071.001', 'T1547.001', 'T1059.003', 'T1588.002', 'T1059.001', 'T1027', 'T1105', 'T1566.001', 'T1204.002']

# %%
# 读取JSON文件
with open('../clustering/cluster_data_pre0_cutoff2.json', 'r') as json_file:
    data_clustering = json.load(json_file)
# 创建一个空的DataFrame来存储technique_id_1和technique_id_2
columns = ['technique_id_1', 'technique_id_2']
result_df = pd.DataFrame(columns=columns)

# 统计高频节点不存在的次数
high_frequency_not_exist = 0

# 遍历聚类数据
for cluster_id, techniques in data_clustering.items():
    high_frequency_present = False  # 标志是否有Technique在high_frequency_id列表中
    
    # 检查聚类中的每个Technique是否至少有一个在high_frequency_id列表中
    for technique in techniques:
        if technique in high_frequency_id:
            high_frequency_present = True
            break
    
    # 如果至少有一个Technique在high_frequency_id列表中，构建关系
    if high_frequency_present:
        for i in range(len(techniques)):
            print(techniques[i])
            for j in range(i + 1, len(techniques)):
                result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
    else:
        # 如果聚类中没有Technique在high_frequency_id列表中，增加计数
        high_frequency_not_exist += 1 
print(high_frequency_not_exist)
print(result_df)
# Out:
# T1583.001
# T1071.001
# T1547.001
# T1059.001
# T1059.003
# T1059.005
# T1005
# T1140
# T1189
# T1203
# T1083
# T1070.004
# T1105
# T1027
# T1036.005
# T1003.001
# T1588.002
# T1566.001
# T1204.002
# T1566.002
# T1204.001
# T1057
# T1082
# T1021.001
# T1018
# T1053.005
# T1016
# T1049
# T1033
# T1078
# T1047
# 196
#   technique_id_1 technique_id_2
# 0      T1071.001      T1547.001
# 1      T1059.001      T1059.003
# 2          T1105          T1027
# 3      T1566.001      T1204.002
# 4      T1566.002      T1204.001
# 5          T1057          T1082
# 6          T1016          T1049
# /tmp/ipykernel_5705/2907418690.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2907418690.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2907418690.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2907418690.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2907418690.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2907418690.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2907418690.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)

# %%
# 读取JSON文件
with open('../clustering/cluster_data_pre0_cutoff3.json', 'r') as json_file:
    data_clustering = json.load(json_file)
# 创建一个空的DataFrame来存储technique_id_1和technique_id_2
columns = ['technique_id_1', 'technique_id_2']
result_df = pd.DataFrame(columns=columns)

# 统计高频节点不存在的次数
high_frequency_not_exist = 0

# 遍历聚类数据
for cluster_id, techniques in data_clustering.items():
    high_frequency_present = False  # 标志是否有Technique在high_frequency_id列表中
    
    # 检查聚类中的每个Technique是否至少有一个在high_frequency_id列表中
    for technique in techniques:
        if technique in high_frequency_id:
            high_frequency_present = True
            break
    
    # 如果至少有一个Technique在high_frequency_id列表中，构建关系
    if high_frequency_present:
        for i in range(len(techniques)):
            print(techniques[i])
            for j in range(i + 1, len(techniques)):
                result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
    else:
        # 如果聚类中没有Technique在high_frequency_id列表中，增加计数
        high_frequency_not_exist += 1 
print(high_frequency_not_exist)
print(result_df)
# Out:
# T1087.002
# T1021.002
# T1018
# T1583.001
# T1583.006
# T1036
# T1218.011
# T1102.002
# T1071.001
# T1547.001
# T1140
# T1105
# T1027
# T1560.001
# T1190
# T1003.001
# T1588.002
# T1505.003
# T1059.001
# T1059.003
# T1070.004
# T1021.001
# T1053.005
# T1047
# T1059.005
# T1566.002
# T1204.001
# T1555.005
# T1189
# T1070.005
# T1055.012
# T1053.002
# T1608.004
# T1074.001
# T1005
# T1056.001
# T1074.002
# T1133
# T1078
# T1041
# T1574.002
# T1016
# T1049
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# T1033
# T1203
# T1566.001
# T1204.002
# T1083
# T1036.005
# T1057
# T1082
# 80
#    technique_id_1 technique_id_2
# 0       T1087.002      T1021.002
# 1       T1087.002          T1018
# 2       T1021.002          T1018
# 3       T1583.001      T1583.006
# 4       T1583.001          T1036
# ..            ...            ...
# 86          T1083          T1057
# 87          T1083          T1082
# 88      T1036.005          T1057
# 89      T1036.005          T1082
# 90          T1057          T1082
#
# [91 rows x 2 columns]
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/2049068890.py:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)

# %%
# 读取JSON文件
with open('../clustering/cluster_data_pre01_cutoff2.json', 'r') as json_file:
    data_clustering = json.load(json_file)
# 创建一个空的DataFrame来存储technique_id_1和technique_id_2
columns = ['technique_id_1', 'technique_id_2']
result_df = pd.DataFrame(columns=columns)

# 统计高频节点不存在的次数
high_frequency_not_exist = 0

# 遍历聚类数据
for cluster_id, techniques in data_clustering.items():
    high_frequency_present = False  # 标志是否有Technique在high_frequency_id列表中
    
    # 检查聚类中的每个Technique是否至少有一个在high_frequency_id列表中
    for technique in techniques:
        if technique in high_frequency_id:
            high_frequency_present = True
            break
    
    # 如果至少有一个Technique在high_frequency_id列表中，构建关系
    if high_frequency_present:
        for i in range(len(techniques)):
            print(techniques[i])
            for j in range(i + 1, len(techniques)):
                result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
    else:
        # 如果聚类中没有Technique在high_frequency_id列表中，增加计数
        high_frequency_not_exist += 1 
print(high_frequency_not_exist)
print(result_df)
# Out:
# T1583.001
# T1071.001
# T1547.001
# T1059.001
# T1059.003
# T1059.005
# T1005
# T1140
# T1189
# T1608.004
# T1203
# T1083
# T1070.004
# T1105
# T1027
# T1036.005
# T1003.001
# T1588.002
# T1566.001
# T1204.002
# T1566.002
# T1204.001
# T1057
# T1082
# T1021.001
# T1018
# T1053.005
# T1016
# T1049
# T1033
# T1078
# T1047
# 150
#   technique_id_1 technique_id_2
# 0      T1071.001      T1547.001
# 1      T1059.001      T1059.003
# 2          T1189      T1608.004
# 3          T1105          T1027
# 4      T1566.001      T1204.002
# 5      T1566.002      T1204.001
# 6          T1057          T1082
# 7          T1016          T1049
# /tmp/ipykernel_5705/495389429.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/495389429.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/495389429.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/495389429.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/495389429.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/495389429.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/495389429.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/495389429.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)

# %%
# 读取JSON文件
with open('../clustering/cluster_data_pre01_cutoff3.json', 'r') as json_file:
    data_clustering = json.load(json_file)
# 创建一个空的DataFrame来存储technique_id_1和technique_id_2
columns = ['technique_id_1', 'technique_id_2']
result_df = pd.DataFrame(columns=columns)

# 统计高频节点不存在的次数
high_frequency_not_exist = 0

# 遍历聚类数据
for cluster_id, techniques in data_clustering.items():
    # 检查聚类中的每个Technique是否在high_frequency_id列表中
    if all(technique in high_frequency_id for technique in techniques):
        # 如果都在，将Technique存储在technique_id_1和technique_id_2列中
        for i in range(len(techniques)):
            for j in range(i + 1, len(techniques)):
                result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
    else:
        # 如果有Technique不在high_frequency_id列表中，增加计数
        high_frequency_not_exist += 1

print(high_frequency_not_exist)
print(result_df)
# Out:
# 59
#    technique_id_1 technique_id_2
# 0       T1071.001      T1547.001
# 1       T1071.001          T1140
# 2       T1071.001          T1105
# 3       T1071.001          T1027
# 4       T1547.001          T1140
# 5       T1547.001          T1105
# 6       T1547.001          T1027
# 7           T1140          T1105
# 8           T1140          T1027
# 9           T1105          T1027
# 10      T1059.001      T1059.003
# 11      T1059.001      T1070.004
# 12      T1059.001      T1021.001
# 13      T1059.001      T1053.005
# 14      T1059.001          T1047
# 15      T1059.003      T1070.004
# 16      T1059.003      T1021.001
# 17      T1059.003      T1053.005
# 18      T1059.003          T1047
# 19      T1070.004      T1021.001
# 20      T1070.004      T1053.005
# 21      T1070.004          T1047
# 22      T1021.001      T1053.005
# 23      T1021.001          T1047
# 24      T1053.005          T1047
# 25      T1059.005      T1566.002
# 26      T1059.005      T1204.001
# 27      T1566.002      T1204.001
# 28          T1203      T1566.001
# 29          T1203      T1204.002
# 30      T1566.001      T1204.002
# 31          T1057          T1082
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
# /tmp/ipykernel_5705/821113451.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'technique_id_1': techniques[i], 'technique_id_2': techniques[j]}, ignore_index=True)
